# %% [markdown]
# # Linear Regression

# %%
# %matplotlib widget

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %% [markdown]
# #### Generate Data

# %%
jumlah_data = 200

y = np.array ([i*0.01 + np.random.rand () for i in range (jumlah_data)])
x = np.array ([i*0.01 for i in range (jumlah_data)])

# %% [markdown]
# #### Fungsi Linear

# %%
def linear_function (x, m):
    return x*m

# %% [markdown]
# ##### Prediksi

# %%
x_prediksi = np.array ([0,10])
m_awal = 5
y_prediksi = linear_function (x_prediksi, m_awal)

# %% [markdown]
# ##### Gambar Prediksi kita

# %%
"""
plt.scatter (x, y)
plt.plot (x_prediksi, y_prediksi)
plt.axis ([0,2,0,3])
plt.show ()
"""
# Out:
# '\nplt.scatter (x, y)\nplt.plot (x_prediksi, y_prediksi)\nplt.axis ([0,2,0,3])\nplt.show ()\n'

# %% [markdown]
# #### Menghitung

# %%
m_prediksi = m_awal

m_list_prediksi = []
y_list_prediksi = []
x_list_prediksi = []

learning_rate = 0.1

#Loopingan buat sebanyak data

for i in range (1,jumlah_data) :

    y_prediksi = linear_function (x[i], m_prediksi)
    y_aktual = y[i]
    
    error = y_aktual - y_prediksi
    delta_m = learning_rate*error/x[i]
    m_prediksi = m_prediksi + delta_m

    m_list_prediksi.append ([m_prediksi])
    y_list_prediksi.append ([y_prediksi])
    x_list_prediksi.append ([x[i]])

# %% [markdown]
# #### Menampilkan Plot

# %%
fig = plt.figure (figsize=(6,6))
line, = plt.plot ([], [])

def animate (num):

    x = [0, x_list_prediksi [num]]
    y = [0, y_list_prediksi [num]]
    line.set_data((x, y))
    return line

plt.scatter (x, y)
plt.axis ([0,2,0,3])

#a = FuncAnimation ()
anime = FuncAnimation (fig, animate, frames=100, interval=200, repeat=False)
plt.show ()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/Belajar Python/Machine Learning/00-Linear Regression/Env/lib/python3.10/site-packages/ipympl/backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File ~/Documents/Belajar Python/Machine Learning/00-Linear Regression/Env/lib/python3.10/site-packages/matplotlib/backends/backend_webagg_core.py:464, in FigureManagerWebAgg.handle_json(self, content)
#     463 def handle_json(self, content):
# --> 464     self.canvas.handle_event(content)
#
# ...
